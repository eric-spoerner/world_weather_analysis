# %%
# TODO: encapsulate mapping tool into single func
# TODO: enable pretty print

# %%
import pandas as pd
import requests
import os.path
import gmaps
from config import g_key
from pprint import pprint

# %%
city_data_df = pd.read_csv(os.path.join("weather_data", "cities.csv"))
city_data_df
# Out:
#      City_ID          City Country                 Date      Lat     Long  \
# 0          0     Cape Town      ZA  2021-12-22 23:58:33 -33.9258  18.4232
# 1          1        Torbay      CA  2021-12-23 00:03:19  47.6666 -52.7314
# 2          2  Punta Arenas      CL  2021-12-23 00:02:26 -53.1500 -70.9167
# 3          3   Port Alfred      ZA  2021-12-23 00:03:25 -33.5906  26.8910
# 4          4         Sivas      TR  2021-12-23 00:03:25  39.7916  37.0019
# ..       ...           ...     ...                  ...      ...      ...
# 498      498  Snezhnogorsk      RU  2021-12-23 00:06:43  69.1933  33.2531
# 499      499      Iracoubo      GF  2021-12-23 00:06:44   5.4802 -53.2011
# 500      500      Buchanan      LR  2021-12-23 00:06:44   5.8808 -10.0467
# 501      501        Abaete      BR  2021-12-23 00:06:45 -19.1600 -45.4458
# 502      502        Rawson      AR  2021-12-23 00:06:45 -43.3002 -65.1023
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       68.41        79           0        4.00
# 1       25.39        87          85        1.01
# 2       60.12        51          82       12.82
# 3       66.51        86          96        7.87
# 4       11.03        85          75        6.91
# ..        ...       ...         ...         ...
# 498     13.78        91         100       12.50
# 499     77.32        92         100        9.24
# 500     79.29        82          32        4.25
# 501     73.80        79          69        3.38
# 502     64.40        68           0       17.52
#
# [503 rows x 10 columns]

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Long          float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
gmaps.configure(api_key=g_key)

# %% [markdown]
# ## Make a heatmap of locations
#
# ### Start with temperature

# %%
# Assign locations to an array of lat/long pairs
locations = city_data_df[["Lat", "Long"]]

# Assign weights variable to some values
max_temp = city_data_df["Max Temp"]
        
#Assign a fig to the gmaps.figure() attribute
fig = gmaps.figure(center=(0.0, 0.0), 
                   zoom_level=1.5,
                   layout = {'width': '800px',
                             'height': '500px'})

# #assign heatmap layer variable t o heatmap layer attrib and add other dfs
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=[max(temp,0) for temp in max_temp],
                                 dissipating=False,
                                 point_radius=3,
                                 max_intensity=0.95)

# # #Add the heatmap layer.
fig.add_layer(heat_layer)

# #Call the figure
fig
# Out:
# Figure(layout=FigureLayout(height='500px', width='800px'))

# %% [markdown]
# ### Humidity

# %%
locations = city_data_df[["Lat", "Long"]]
humidity = city_data_df["Humidity"]

fig = gmaps.figure(center=(0.0, 0.0), 
                   zoom_level=1.5,
                   layout = {'width': '800px',
                             'height': '500px'})

heat_layer = gmaps.heatmap_layer(locations,
                                 weights=humidity,
                                 dissipating=False,
                                 point_radius=3,
                                 max_intensity=0.95)

fig.add_layer(heat_layer)


fig
# Out:
# Figure(layout=FigureLayout(height='500px', width='800px'))

# %% [markdown]
# ### Cloudiness

# %%
locations = city_data_df[["Lat", "Long"]]
clouds = city_data_df["Cloudiness"]

fig = gmaps.figure(center=(0.0, 0.0), 
                   zoom_level=1.5,
                   layout = {'width': '800px',
                             'height': '500px'})

heat_layer = gmaps.heatmap_layer(locations,
                                 weights=clouds,
                                 dissipating=False,
                                 point_radius=3,
                                 max_intensity=0.95)

fig.add_layer(heat_layer)


fig
# Out:
# Figure(layout=FigureLayout(height='500px', width='800px'))

# %% [markdown]
# ### Wind speed

# %%
locations = city_data_df[["Lat", "Long"]]
wind_speed = city_data_df["Wind Speed"]

fig = gmaps.figure(center=(0.0, 0.0), 
                   zoom_level=1.5,
                   layout = {'width': '800px',
                             'height': '500px'})

heat_layer = gmaps.heatmap_layer(locations,
                                 weights=wind_speed,
                                 dissipating=False,
                                 point_radius=3,
                                 max_intensity=0.95)

fig.add_layer(heat_layer)


fig
# Out:
# Figure(layout=FigureLayout(height='500px', width='800px'))

# %% [markdown]
# ## Plot vacation data

# %%
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & (city_data_df["Max Temp"] <= max_temp)]
# Out:
# What is the minimum temperature you would like for your trip?  65
# What is the maximum temperature you would like for your trip?  80

# %%
preferred_cities_df.count()
# Out:
# City_ID       174
# City          174
# Country       173
# Date          174
# Lat           174
# Long          174
# Max Temp      174
# Humidity      174
# Cloudiness    174
# Wind Speed    174
# dtype: int64

# %%
preferred_cities_df = preferred_cities_df.dropna()
preferred_cities_df
# Out:
#      City_ID          City Country                 Date      Lat      Long  \
# 0          0     Cape Town      ZA  2021-12-22 23:58:33 -33.9258   18.4232
# 3          3   Port Alfred      ZA  2021-12-23 00:03:25 -33.5906   26.8910
# 5          5         Rafai      CF  2021-12-23 00:03:25   4.9500   23.9167
# 7          7        Atuona      PF  2021-12-23 00:03:26  -9.8000 -139.0333
# 15        15  Ponta Do Sol      PT  2021-12-23 00:03:30  32.6667  -17.1000
# ..       ...           ...     ...                  ...      ...       ...
# 495      495        Bukama      CD  2021-12-23 00:06:42  -9.2000   25.8500
# 497      497     Kisangani      CD  2021-12-23 00:06:43   0.5167   25.2000
# 499      499      Iracoubo      GF  2021-12-23 00:06:44   5.4802  -53.2011
# 500      500      Buchanan      LR  2021-12-23 00:06:44   5.8808  -10.0467
# 501      501        Abaete      BR  2021-12-23 00:06:45 -19.1600  -45.4458
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       68.41        79           0        4.00
# 3       66.51        86          96        7.87
# 5       72.50        47          99        3.11
# 7       78.89        75          17       20.31
# 15      67.01        90          81        8.88
# ..        ...       ...         ...         ...
# 495     69.37        97         100        2.57
# 497     73.74        72          97        1.74
# 499     77.32        92         100        9.24
# 500     79.29        82          32        4.25
# 501     73.80        79          69        3.38
#
# [173 rows x 10 columns]

# %%
hotel_df = preferred_cities_df[["City", "Country","Max Temp", "Lat", "Long"]]
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
# C:\Users\espoe\anaconda3\envs\gmaps\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              City Country  Max Temp      Lat      Long Hotel Name
# 0       Cape Town      ZA     68.41 -33.9258   18.4232
# 3     Port Alfred      ZA     66.51 -33.5906   26.8910
# 5           Rafai      CF     72.50   4.9500   23.9167
# 7          Atuona      PF     78.89  -9.8000 -139.0333
# 15   Ponta Do Sol      PT     67.01  32.6667  -17.1000
# ..            ...     ...       ...      ...       ...        ...
# 495        Bukama      CD     69.37  -9.2000   25.8500
# 497     Kisangani      CD     73.74   0.5167   25.2000
# 499      Iracoubo      GF     77.32   5.4802  -53.2011
# 500      Buchanan      LR     79.29   5.8808  -10.0467
# 501        Abaete      BR     73.80 -19.1600  -45.4458
#
# [173 rows x 6 columns]

# %%
# try it once with paris
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# g_key

# coords = str(f"{hotel_df.loc[0]["Lat"]}, {hotel_df.loc[0]["Long"]}")
# coords

params = {'key':g_key,
          'location':"48.8566, 2.3522",
            'radius':5000,
           'type':'lodging'}

hotels = requests.get(base_url, params=params).json()
len(hotels)
# Out:
# 4

# %%
pprint(hotels["results"][0])
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#               'viewport': {'northeast': {'lat': 48.8594360302915,
#                                          'lng': 2.354355480291502},
#                            'southwest': {'lat': 48.8567380697085,
#                                          'lng': 2.351657519708498}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#  'icon_background_color': '#909CE1',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#  'name': 'Hôtel Duo',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 3840,
#              'html_attributions': ['<a '
#                                    'href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel '
#                                    'Duo</a>'],
#              'photo_reference': 'Aap_uEDU7QWQ7NzUKmwbokms31gfRrV_q5RLWsLtK2csrSlzJzcamS5M7v29M5zBv8fTezSJSC7QSxvEWHO_7MkkoE_5kb1byFzLRAvc2AluqVikL1wtZm4idw1HdEIwjcK-P2Gm1auxvMeeJO2N3iPchbhv_ulyVrZx2ZeJVeRPD4GWmGLp',
#              'width': 5760}],
#  'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#  'plus_code': {'compound_code': 'V953+65 Paris, France',
#                'global_code': '8FW4V953+65'},
#  'rating': 4.2,
#  'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#  'scope': 'GOOGLE',
#  'types': ['night_club',
#            'spa',
#            'lodging',
#            'bar',
#            'gym',
#            'health',
#            'point_of_interest',
#            'establishment'],
#  'user_ratings_total': 314,
#  'vicinity': '11 Rue du Temple, Paris'}

# %%
# try it once with single city
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# g_key

city_lat = hotel_df.loc[0]["Lat"]
city_long = hotel_df.loc[0]["Long"]

coords = str(f"{city_lat},{city_long}")
coords

params = {'key':g_key,
          'location':coords,
            'radius':5000,
           'type':'lodging'}

hotels = requests.get(base_url, params=params).json()
len(hotels)
pprint(hotels)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECG0sufTSNFskWjQm6sbbOYuNuol11VhSoCuRGjnNlkOqtP5dz2t-vkXAlMN5ecrIWkKmB_qk2OLbLdgrIRyFfktSsk6DoysM2a-6nrryHPklw36yMdDhfVKzskjufhkUDzzFPXydHWVCreiIO-7w-VDjNvQ_hK6M4GunhQ4qcfQwxofQN8V2OmT9oh7vIXykMqSau1bE0uYH5sJkSdjRLq-huSa-TAAyfSZLq2YZSxZ-GYAqDMt5l5Leq3Sh-sf_-LEh0K5zg9qzxSmP9BqPoKOu5xf2offFKvfCLq9SFzyW51i0bXBQsmGqm4Y_nEJJBobBJdNQsQ0zprDEh3PyxE71q54KNE27PEZn-GHRjgEGoPgNERxK8uQruOPKglAspbX1v2V74OzI65kKYvO--59cWJagg7yCw9SomqEy9oYE5lOZ6hL_Ft',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9157633, 'lng': 18.4234956},
#                            'viewport': {'northeast': {'lat': -33.9143788197085,
#                                                       'lng': 18.42475433029151},
#                                         'southwest': {'lat': -33.9170767802915,
#                                                       'lng': 18.4220563697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Southern Sun Waterfront Cape Town',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118270743309610256539">Southern '
#                                                 'Sun Waterfront Cape Town</a>'],
#                           'photo_reference': 'Aap_uEDEIAzlX1FgwdMiClPnSg0kWAMXh7O-DxCQyu4zYQsvJuflPA4OWHkAH5PLTT2it6NTa56GyiKek7i9FkkZSIK1Dfg_chPNd_vB8y-Ea6gPIUbvxUlK7kvvzeNgXmUYVHwKvqBKPIaVWM5AktmgziX7zxCKr0dJyqjgsit4-4gKGfCy',
#                           'width': 1080}],
#               'place_id': 'ChIJN5zkbXJnzB0RxqS-7dZAVJY',
#               'plus_code': {'compound_code': '3CMF+M9 Cape Town, South Africa',
#                             'global_code': '4FRW3CMF+M9'},
#               'rating': 4.4,
#               'reference': 'ChIJN5zkbXJnzB0RxqS-7dZAVJY',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 2813,
#               'vicinity': '1 Lower Buitengracht, Cape Town City Centre, Cape '
#                           'Town'},
#              {'business_status': 'CLOSED_TEMPORARILY',
#               'geometry': {'location': {'lat': -33.9214218, 'lng': 18.4220856},
#                            'viewport': {'northeast': {'lat': -33.9200460697085,
#                                                       'lng': 18.4234635302915},
#                                         'southwest': {'lat': -33.9227440302915,
#                                                       'lng': 18.4207655697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Southern Sun Cape Sun',
#               'permanently_closed': True,
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114412712237243254381">Southern '
#                                                 'Sun Cape Sun</a>'],
#                           'photo_reference': 'Aap_uECsP_Uv-s0Vag_PEpPxHJbATk1Az8peZ-FWiW3MCOnpnM_R0rksqtk791bNQC-RWj7znnKbBMU1QbsQq6jnnp6jHGhrFjB5RF8getF2pEhD-nr0kP4E6DHeN-CsapJT9zr67WOMXI2yjolZSW2YBUZuxaws6a711akuaRfCZcGy9pDB',
#                           'width': 1080}],
#               'place_id': 'ChIJO7IY-WNnzB0RlOIFGBy96qQ',
#               'plus_code': {'compound_code': '3CHC+CR Cape Town, South Africa',
#                             'global_code': '4FRW3CHC+CR'},
#               'rating': 4.4,
#               'reference': 'ChIJO7IY-WNnzB0RlOIFGBy96qQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2917,
#               'vicinity': '23 Strand Street, Cape Town City Centre, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.92109, 'lng': 18.42043},
#                            'viewport': {'northeast': {'lat': -33.9197847197085,
#                                                       'lng': 18.4218367802915},
#                                         'southwest': {'lat': -33.9224826802915,
#                                                       'lng': 18.4191388197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'The Grand Daddy Boutique Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1179,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115957286771107494080">The '
#                                                 'Grand Daddy Boutique '
#                                                 'Hotel</a>'],
#                           'photo_reference': 'Aap_uECmDs6lZJmY5sUDxGY4dL-dMhngYC4NIzujHuWJK9gD7qSPVav9Q5jgzHSqfWGgl7YA62zziy6pRXPqPP6mp7VHnfKyPhmzAULrZmLej8AmVM3LRfKUqYNDX5C-1RBgYA49-M8UibSXPwOq0bIfwAMtb6Dgfrw-hiOI4CEjglThNN9c',
#                           'width': 1766}],
#               'place_id': 'ChIJuycyoWZnzB0RFPftt4xTZqc',
#               'plus_code': {'compound_code': '3CHC+H5 Cape Town, South Africa',
#                             'global_code': '4FRW3CHC+H5'},
#               'rating': 4.3,
#               'reference': 'ChIJuycyoWZnzB0RFPftt4xTZqc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 639,
#               'vicinity': '38 Long Street, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.924356, 'lng': 18.4210457},
#                            'viewport': {'northeast': {'lat': -33.9229691197085,
#                                                       'lng': 18.4223436302915},
#                                         'southwest': {'lat': -33.92566708029149,
#                                                       'lng': 18.4196456697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Adderley Hotel',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1200,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118235352038121428837">Igmar</a>'],
#                           'photo_reference': 'Aap_uECm_DvSk-TAlB6EBaq7Ae_4qbZuEJH1EPrOJVBdoKCGpGVCczEfMV69uFbw1tLb71GoZ2UHSo9dn1NwIYODsLgiayAJZZrafdFt0U1E20IGnIh9CsHA2o3RI8jiJnjXQdfn3VFCLXWKYhQqjbJsLRkVx19vDMTRNVzUvSNOcoG9Tis8',
#                           'width': 819}],
#               'place_id': 'ChIJx6CYhWRnzB0R3iitaANFkoo',
#               'plus_code': {'compound_code': '3CGC+7C Cape Town, South Africa',
#                             'global_code': '4FRW3CGC+7C'},
#               'rating': 4,
#               'reference': 'ChIJx6CYhWRnzB0R3iitaANFkoo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 69,
#               'vicinity': 'Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.92837639999999,
#                                         'lng': 18.4138214},
#                            'viewport': {'northeast': {'lat': -33.9269887197085,
#                                                       'lng': 18.4150574302915},
#                                         'southwest': {'lat': -33.9296866802915,
#                                                       'lng': 18.4123594697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'The Capital 15 on Orange Hotel',
#               'photos': [{'height': 1996,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110349137429669407664">15 '
#                                                 'On Orange Hotel, The '
#                                                 'Capital</a>'],
#                           'photo_reference': 'Aap_uEDgkg88jVKyBNT2eU7r91XHeTxegKgM60lOGcFB-ZtIMKbw9_taC3s5qxmqji24QmNDHCR9BLWKZMlo21k9mFcvHTG0NaKmzRrB0bYODK72Wn-Ofeiil3KODI4vtQgSFJorfQPfE8P1B3tn_eV5cRUD6EIwkU9GREXPg9YhRJvJg7c',
#                           'width': 3000}],
#               'place_id': 'ChIJSQLGJnBnzB0RE32jV0e-xgU',
#               'plus_code': {'compound_code': '3CC7+JG Cape Town, South Africa',
#                             'global_code': '4FRW3CC7+JG'},
#               'rating': 4.6,
#               'reference': 'ChIJSQLGJnBnzB0RE32jV0e-xgU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1375,
#               'vicinity': "Corner Of Orange Street & Grey's Pass, Gardens, "
#                           'Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.92645580000001,
#                                         'lng': 18.41203269999999},
#                            'viewport': {'northeast': {'lat': -33.9252445697085,
#                                                       'lng': 18.4130464302915},
#                                         'southwest': {'lat': -33.9279425302915,
#                                                       'lng': 18.4103484697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Protea Hotel Fire & Ice! Cape Town',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109753461114390990816">Protea '
#                                                 'Hotel Fire &amp; Ice! Cape '
#                                                 'Town</a>'],
#                           'photo_reference': 'Aap_uEDfvRC_dLY2Fejq0zGrcWkjww83ZD6vfPaqVNqUZNtGKh-e0X1J_GZpRfNLmbiOg7bqPm5EMqIc6IacsZO79IqVj1s4WwdO9YMBZu5zZynapQqWQRojc430tJPN8KkfI4WEWAXjJ_1_Hp5Kbl29E69uTDD5oEZiu8EqF08xKxwzwICW',
#                           'width': 2048}],
#               'place_id': 'ChIJF9UnQW5nzB0Rg2GL-DEDkwc',
#               'plus_code': {'compound_code': '3CF6+CR Cape Town, South Africa',
#                             'global_code': '4FRW3CF6+CR'},
#               'rating': 4.2,
#               'reference': 'ChIJF9UnQW5nzB0Rg2GL-DEDkwc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2704,
#               'vicinity': '64 New Church Street, Tamboerskloof, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.91659519999999,
#                                         'lng': 18.4238657},
#                            'viewport': {'northeast': {'lat': -33.91524621970849,
#                                                       'lng': 18.4252146802915},
#                                         'southwest': {'lat': -33.91794418029149,
#                                                       'lng': 18.42251671970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Protea Hotel by Marriott Cape Town North Wharf',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116771906649193745981">Protea '
#                                                 'Hotel by Marriott Cape Town '
#                                                 'North Wharf</a>'],
#                           'photo_reference': 'Aap_uEAlxsGEo8kEcb5A6NByjxbh4E5TgOHjNf8pbY4na-XkbQlaSliiNEV-sGYBmT4WpLnN9SDUgQFYH71P8fpc7o7GsCJb4sEHYZcm2t2C0aWzihSmcKQ0zj86GpTlVYtB9HbIzIbqGqpFvLGBN51X2FFGjwbG95JesXErZz3XWXuP1No6',
#                           'width': 2048}],
#               'place_id': 'ChIJq7mtmmBnzB0RySWyuzhYRls',
#               'plus_code': {'compound_code': '3CMF+9G Cape Town, South Africa',
#                             'global_code': '4FRW3CMF+9G'},
#               'rating': 4.4,
#               'reference': 'ChIJq7mtmmBnzB0RySWyuzhYRls',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 400,
#               'vicinity': '1 Lower, Bree Street, Foreshore, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9135569, 'lng': 18.4261525},
#                            'viewport': {'northeast': {'lat': -33.9122686697085,
#                                                       'lng': 18.4273676302915},
#                                         'southwest': {'lat': -33.9149666302915,
#                                                       'lng': 18.4246696697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'aha Harbour Bridge Hotel & Suites',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4912,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115990826938843063486">aha '
#                                                 'Harbour Bridge Hotel &amp; '
#                                                 'Suites</a>'],
#                           'photo_reference': 'Aap_uEBIXBisgO0FEx9LK7zKYxXbMGFj_Cx53KOGtI1j0oE9ip5oTq0cYXg1hB39EHTM9Qc3770E9v3gln9JWjT348njOeBuUBLhZvoYyHZbzJXkbU4Sq7wenbiZ2bOpUO3KV2vmt1MnCVTuwSKuG_KXusYkxn92DwM0bliwhoNtSl1CqBEO',
#                           'width': 7360}],
#               'place_id': 'ChIJQasY_GBnzB0RK7l_yzvwv8g',
#               'plus_code': {'compound_code': '3CPG+HF Cape Town, South Africa',
#                             'global_code': '4FRW3CPG+HF'},
#               'rating': 4.3,
#               'reference': 'ChIJQasY_GBnzB0RK7l_yzvwv8g',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'bar',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 903,
#               'vicinity': 'Dockrail Road, Foreshore, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.924751, 'lng': 18.4218687},
#                            'viewport': {'northeast': {'lat': -33.9233057697085,
#                                                       'lng': 18.4233214302915},
#                                         'southwest': {'lat': -33.9260037302915,
#                                                       'lng': 18.4206234697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Cape Diamond Boutique Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1200,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106313642875239382076">Cape '
#                                                 'Diamond Boutique Hotel</a>'],
#                           'photo_reference': 'Aap_uEAH5IAu8Vyk4m79j7J7wxPFV9wtNL4zw6wGdQg0ZNSS-95Sfk0xy5vFwZSkjatr88eIsIX1pT2xkKEccuSuFQoVt2RAc_3cz6wWRPmmc3fP9O62AikvSAg_dNcFX8xbjDvsh8Kpt1ScbNEIcmcZMwJHsVXDxJQygKR_mfno1v2Noiyq',
#                           'width': 1700}],
#               'place_id': 'ChIJ01PYfGNnzB0RQDNhnY83rio',
#               'plus_code': {'compound_code': '3CGC+3P Cape Town, South Africa',
#                             'global_code': '4FRW3CGC+3P'},
#               'rating': 3.8,
#               'reference': 'ChIJ01PYfGNnzB0RQDNhnY83rio',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 547,
#               'vicinity': '34 Longmarket Street, Cape Town City Centre, Cape '
#                           'Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.92402909999999,
#                                         'lng': 18.41907269999999},
#                            'viewport': {'northeast': {'lat': -33.9227079697085,
#                                                       'lng': 18.4206735302915},
#                                         'southwest': {'lat': -33.9254059302915,
#                                                       'lng': 18.4179755697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Mandela Rhodes Place Hotel and Spa',
#               'photos': [{'height': 542,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102929072074056483404">Mandela '
#                                                 'Rhodes Place Hotel and '
#                                                 'Spa</a>'],
#                           'photo_reference': 'Aap_uECqgOFuHRPxObtcfOl4OdEZ8vN0di_1WXSlKrRgf4vQUVaKiazPOR6Oli2lv2pVN-fYqv1FI6QloXH85d6HlyFvtsDkgWybPntHLUvqSNak-O5ixvKigpgxVlhYzz4EVH_pT9lchmVeEaBs9kjFrq6fn-nyIhHsoNSmXboLLcZaWUa4',
#                           'width': 548}],
#               'place_id': 'ChIJ4dFOq2VnzB0RaC_-cWQqDVQ',
#               'plus_code': {'compound_code': '3CG9+9J Cape Town, South Africa',
#                             'global_code': '4FRW3CG9+9J'},
#               'rating': 4.4,
#               'reference': 'ChIJ4dFOq2VnzB0RaC_-cWQqDVQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 514,
#               'vicinity': 'Wale St & Burg St, Cape Town City Centre, Cape '
#                           'Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9331363, 'lng': 18.4107843},
#                            'viewport': {'northeast': {'lat': -33.93181706970851,
#                                                       'lng': 18.4121081302915},
#                                         'southwest': {'lat': -33.93451503029151,
#                                                       'lng': 18.4094101697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Lady Hamilton Hotel',
#               'photos': [{'height': 613,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114595292019292685373">Lady '
#                                                 'Hamilton Hotel</a>'],
#                           'photo_reference': 'Aap_uED-awD0NqRhMkVDAEpsS4tICCjeGKG3E4IpvXUXCF0k5ZLvDAdj6D4tMOX47CgZkrqOJW3cBzfBcxSuJSREOKMwIQVD84BiwhleSckKM7c-qj2s6XOEiwkx3xnTdjwrxil8-yyIlsBCVVTQgbMSUXC90zqvRvhOEVl9ZnmmEaxXTznT',
#                           'width': 881}],
#               'place_id': 'ChIJd81YSXFnzB0RKcXrY9W6sug',
#               'plus_code': {'compound_code': '3C86+P8 Cape Town, South Africa',
#                             'global_code': '4FRW3C86+P8'},
#               'rating': 3.4,
#               'reference': 'ChIJd81YSXFnzB0RKcXrY9W6sug',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 351,
#               'vicinity': '10 Union Street, Gardens, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9288, 'lng': 18.4108},
#                            'viewport': {'northeast': {'lat': -33.9274236697085,
#                                                       'lng': 18.4121805802915},
#                                         'southwest': {'lat': -33.9301216302915,
#                                                       'lng': 18.4094826197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hippo Boutique Hotel',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2268,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101028974869439067291">Dusan '
#                                                 'H.</a>'],
#                           'photo_reference': 'Aap_uECdB_A2pRB1wVYT7viQ1nvrEHZ0XtIwkdyR0r8hYiD7LiRtfA_dB44a5UefrR4pOkBPO_ccb-NnPYWrgBO6_qeI5lsPFT-6oNrl28NwRPKTa28CZxiZlsb63rx1nXaywNGOy1sODFrH-g9jgUrJsAt0TChcW_w3L37HUpOA7pIS-oKc',
#                           'width': 4032}],
#               'place_id': 'ChIJizqF5XFnzB0Rg-n-YV3T_O8',
#               'plus_code': {'compound_code': '3CC6+F8 Cape Town, South Africa',
#                             'global_code': '4FRW3CC6+F8'},
#               'rating': 4.3,
#               'reference': 'ChIJizqF5XFnzB0Rg-n-YV3T_O8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 179,
#               'vicinity': 'Gardens, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.93347000000001,
#                                         'lng': 18.4121649},
#                            'viewport': {'northeast': {'lat': -33.93208076970851,
#                                                       'lng': 18.4134313802915},
#                                         'southwest': {'lat': -33.93477873029151,
#                                                       'lng': 18.4107334197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Ashanti Lodge Gardens',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2768,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109794220106436512635">Ashanti '
#                                                 'Lodge Gardens</a>'],
#                           'photo_reference': 'Aap_uEAe-Yxm2Q4zl74abzuz1T0OuLalIIO6IA2GgD26wtYMe62hGyNUhtbRQ2qeoxGIWmXJTtrIvPahuI4Y2yF-vQeVKnhqiLHFYUtDR9hMJDpXo6dI3gkdJ0edZb58y1KyXfBAsQRvbPEACTba-jw5-Yt0XAVBD_AqFe_UMV3OVghDWOL_',
#                           'width': 5888}],
#               'place_id': 'ChIJ8Xzj0nZnzB0Rkbth5kNV_AY',
#               'plus_code': {'compound_code': '3C86+JV Cape Town, South Africa',
#                             'global_code': '4FRW3C86+JV'},
#               'rating': 4.3,
#               'reference': 'ChIJ8Xzj0nZnzB0Rkbth5kNV_AY',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'travel_agency',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 368,
#               'vicinity': '11 Hof Street, Gardens, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9157055, 'lng': 18.4262212},
#                            'viewport': {'northeast': {'lat': -33.9143596697085,
#                                                       'lng': 18.4275745302915},
#                                         'southwest': {'lat': -33.9170576302915,
#                                                       'lng': 18.4248765697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'The Westin Cape Town',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104099009271760318589">The '
#                                                 'Westin Cape Town</a>'],
#                           'photo_reference': 'Aap_uECIwuJNK8XqGN6ezm2Usn5bs2zqIVr1iHdECbNPXjyyRTtEA3F_9igASL11VROjoO0orQPlfZtBhjp79HDxatU7LNktpNZShnaJGfwapVQT8JRDEwBzm_3_kFpYGmF-qRL3ybsIBB69hSSxxwAN_TqBFkeHA1SAzbdZaVM7j32HTzg8',
#                           'width': 2048}],
#               'place_id': 'ChIJ_YCpaGBnzB0RB4l6g4--5Rs',
#               'plus_code': {'compound_code': '3CMG+PF Cape Town, South Africa',
#                             'global_code': '4FRW3CMG+PF'},
#               'rating': 4.6,
#               'reference': 'ChIJ_YCpaGBnzB0RB4l6g4--5Rs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3351,
#               'vicinity': 'Convention Square, Lower Long Street, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.93419, 'lng': 18.41506},
#                            'viewport': {'northeast': {'lat': -33.9326963197085,
#                                                       'lng': 18.4164076802915},
#                                         'southwest': {'lat': -33.9353942802915,
#                                                       'lng': 18.4137097197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'SunSquare Cape Town Gardens',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 4366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104807619085857519205">SunSquare '
#                                                 'Cape Town Gardens</a>'],
#                           'photo_reference': 'Aap_uEDmxuOKPGQh4M__-4h3dhzO2cMNC5D4OBr7iOtZZejJcbmHiD0-4a-geuWjhrLMU1rWSIvXi5zkRNW0mUUmXqPSB7uIsgVj4uVsy59EHz5IR94oDrbtk3b0t0_uecqLiMRQFaOTvuFZqCiC0J2LQH0Sod3R1Wk7qFS9rqViqh3tbXrK',
#                           'width': 2910}],
#               'place_id': 'ChIJlQVtr3lnzB0RVP6pAVRtEkw',
#               'plus_code': {'compound_code': '3C88+82 Cape Town, South Africa',
#                             'global_code': '4FRW3C88+82'},
#               'rating': 4.2,
#               'reference': 'ChIJlQVtr3lnzB0RVP6pAVRtEkw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 761,
#               'vicinity': '10 Mill Street, Gardens, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9224601, 'lng': 18.4155973},
#                            'viewport': {'northeast': {'lat': -33.9210869697085,
#                                                       'lng': 18.41691443029151},
#                                         'southwest': {'lat': -33.9237849302915,
#                                                       'lng': 18.4142164697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Cape Town Lodge Hotel',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110844220583678393078">chad '
#                                                 'madden</a>'],
#                           'photo_reference': 'Aap_uEDrX7jICbTVmSMzj-6r9t1C3H9eb_WMbWhtChaAcfjVNmsl4syhVYvA7xTDhf-tf6dWGp4j-ffrBfJ74zdmNab4a1OsS8dVzSGSxIDt6OxIkzhePnuJwQB2fiu2lGMRIk6Df3etCPI3gfyaDa-Sv0adSmkel1zTBgxLYBS8yWW3xl9E',
#                           'width': 4032}],
#               'place_id': 'ChIJB8AfVm9nzB0RhuROLv0h8U4',
#               'plus_code': {'compound_code': '3CH8+26 Cape Town, South Africa',
#                             'global_code': '4FRW3CH8+26'},
#               'rating': 4.1,
#               'reference': 'ChIJB8AfVm9nzB0RhuROLv0h8U4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1667,
#               'vicinity': '101 Buitengracht Street, Cape Town City Centre, '
#                           'Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.911352, 'lng': 18.415297},
#                            'viewport': {'northeast': {'lat': -33.9099572197085,
#                                                       'lng': 18.4167054302915},
#                                         'southwest': {'lat': -33.91265518029149,
#                                                       'lng': 18.4140074697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Sugar Hotel',
#               'photos': [{'height': 3000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105425877571912468337">Evelyn '
#                                                 'Gould</a>'],
#                           'photo_reference': 'Aap_uECe6ZBMFCpBGhojdEcOSL3T4moSgQJ11llnRrqjrsH_SMYbg1KEwLmzx25EYLl74nfldWJnJ3hIoW7nDjQejEhZ0wjthqxcnFQk9GzWkpgtEniZ7Ck5j-nYXMbSULFPghsNmIrUgowBOKb77zBXi9unrJeJtluy1gO6kytkMTquy0od',
#                           'width': 4000}],
#               'place_id': 'ChIJMR3xoK1czB0RKRTbjcihzpM',
#               'plus_code': {'compound_code': '3CQ8+F4 Cape Town, South Africa',
#                             'global_code': '4FRW3CQ8+F4'},
#               'rating': 4.3,
#               'reference': 'ChIJMR3xoK1czB0RKRTbjcihzpM',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 315,
#               'vicinity': '1 Main Road, Green Point, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9296764, 'lng': 18.4120906},
#                            'viewport': {'northeast': {'lat': -33.9282945197085,
#                                                       'lng': 18.4133869302915},
#                                         'southwest': {'lat': -33.93099248029149,
#                                                       'lng': 18.4106889697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'The Fritz Hotel',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2240,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106778412272819265860">Christian '
#                                                 'Peeters</a>'],
#                           'photo_reference': 'Aap_uEDJFs1zKYF85JBWx2Q4Au3gBWCLL3DJN0oiMpXm1qJm51Qa8Xkiwh1n1D-_n-ob78sdN2YIBxfbvu9HoL-eNCed3w_bO6nCvCfC2BPBHyPXFn6ip0pzjLaYi7-N2xdS8YxNS-36bZ461GyED22itTvLskweu5qP8HVVahX9Wc7qUwA_',
#                           'width': 3968}],
#               'place_id': 'ChIJrbgzt3FnzB0RYhcBcIhms6E',
#               'plus_code': {'compound_code': '3CC6+4R Cape Town, South Africa',
#                             'global_code': '4FRW3CC6+4R'},
#               'rating': 3.7,
#               'reference': 'ChIJrbgzt3FnzB0RYhcBcIhms6E',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 86,
#               'vicinity': 'Gardens, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.9271422, 'lng': 18.4103656},
#                            'viewport': {'northeast': {'lat': -33.9259088697085,
#                                                       'lng': 18.4118352802915},
#                                         'southwest': {'lat': -33.9286068302915,
#                                                       'lng': 18.4091373197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Villa Viva Cape Town',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1499,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113604843486373262720">Villa '
#                                                 'Viva Backpack</a>'],
#                           'photo_reference': 'Aap_uECzY4vqpz6j2ozxwANmqAXiLvaAmPiRCIFxkeSihRsGjqHcjwUn0aqMkKxW71uFdOxARA7pzcOxSn2c_lYLbz9btysuK5kjzGEwciOLjwfVlnkGY83f5Kc13VMFB3oUCkAUVKQStDAdrRWUWrgpjTuYyVTyS71pkfrSe6vfDlWBPeE',
#                           'width': 2000}],
#               'place_id': 'ChIJS7kbEm5nzB0R-7HuAwKZjHo',
#               'plus_code': {'compound_code': '3CF6+44 Cape Town, South Africa',
#                             'global_code': '4FRW3CF6+44'},
#               'rating': 4.5,
#               'reference': 'ChIJS7kbEm5nzB0R-7HuAwKZjHo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 372,
#               'vicinity': '74 New Church Street, Tamboerskloof, Cape Town'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -33.91273179999999,
#                                         'lng': 18.41727819999999},
#                            'viewport': {'northeast': {'lat': -33.91195861970849,
#                                                       'lng': 18.4188635802915},
#                                         'southwest': {'lat': -33.91465658029149,
#                                                       'lng': 18.41616561970849}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Victoria Junction Hotel, Cape Town',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108318011892655369687">Victoria '
#                                                 'Junction Hotel, Cape '
#                                                 'Twon</a>'],
#                           'photo_reference': 'Aap_uEBEBWM1P4JKDcMoygDAJ2KlpF5X1797E9YZBTnGPdfefuk7KXLwZ4KKK0CFhVhqHBpgjvmDqVHOaEWRJqFncorT_4WLhURgb3R3kCADCsBRaX_ALF-cd_XzTVFi11VH6aBAPO3A7CgmHpoRW9tRC67ztajxZE8A22Tfq0yHiuvEFDhj',
#                           'width': 2048}],
#               'place_id': 'ChIJg4mTxlxnzB0RuO-TjFSGvIE',
#               'plus_code': {'compound_code': '3CP8+WW Cape Town, South Africa',
#                             'global_code': '4FRW3CP8+WW'},
#               'rating': 4.3,
#               'reference': 'ChIJg4mTxlxnzB0RuO-TjFSGvIE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1023,
#               'vicinity': 'Corner Of Somerset And, Ebenezer Road, Green Point, '
#                           'Cape Town'}],
#  'status': 'OK'}

# %%
# iterate through multiple cities
for index, row in hotel_df.iterrows():
    base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

    row
    
    city_lat = row["Lat"]
    city_long = row["Long"]

    coords = str(f"{city_lat},{city_long}")
    coords

    city_name = f"{row['City']}, {row['Country']}"
    
    params = {'key':g_key,
              'location':coords,
                'radius':5000,
               'type':'lodging'}

    hotels = requests.get(base_url, params=params).json()

    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print(f"Identified {hotel_df.loc[index, 'Hotel Name'] } in {city_name}")
    except (IndexError):
        print(f"No hotel found for {city_name}")
# Out:
# Identified Southern Sun Waterfront Cape Town in Cape Town, ZA
# Identified The Halyards Hotel in Port Alfred, ZA
# No hotel found for Rafai, CF
# Identified Villa Enata in Atuona, PF
# Identified Hotel do Campo in Ponta Do Sol, PT
# Identified Hotel Tesoro Los Cabos in Cabo San Lucas, MX
# Identified Finch Bay Galapagos Hotel in Puerto Ayora, EC
# Identified Chambres d'hôte "La Trinité" in Saint-philippe, RE
# Identified Amaralina Hotel in Francisco Sa, BR
# Identified Observatory Guest House in Busselton, AU
# Identified People ThankYou in Rikitea, PF
# Identified Tu Casa in East London, ZA
# Identified Hilo Hawaiian Hotel in Hilo, US
# Identified Hotel Castelo in Cidreira, BR
# Identified BON Hotel Waterfront Richards Bay in Richards Bay, ZA
# Identified Pousada dos Navegantes in Caravelas, BR
# Identified Shandrani Beachcomber Resort & Spa in Mahebourg, MU
# Identified La pousada in Camopi, GF
# Identified Veranda Paul et Virginie Hotel & Spa in Grand Gaube, MU
# Identified Mini Hotel Central in Victoria, HK
# Identified Gran Hotel Mar del Plata in Mar Del Plata, AR
# Identified Hotel Benjamín Hill in Benjamin Hill, MX
# Identified Casona Del Muelle in Pimentel, PE
# Identified Hotel Cristal in Viedma, AR
# Identified Pousada Porto Praia in Arraial Do Cabo, BR
# Identified Floresta Amazonica Hotel in Alta Floresta, BR
# Identified Kitnet do Marcos in Portel, BR
# Identified Ramee Garden Hotel Apartments in Abu Dhabi, AE
# Identified Hotel San Isidro Oficial in Pisco, PE
# No hotel found for Goure, NE
# Identified HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel in Salalah, OM
# No hotel found for Aripuana, BR
# Identified Aviador Hotel Boutique in Santa Cruz, BO
# Identified Motel Fantasy Star in Carolina, PR
# Identified Hôtel Campement in Dabakala, CI
# Identified Mercure Padang in Padang, ID
# Identified Derogongan Residence in Marawi, PH
# Identified Casa Tia Villa in Bambous Virieux, MU
# No hotel found for Uvalde, US
# Identified Hotel Las Casitas Santa Rosalia in Santa Rosalia, MX
# No hotel found for Beloha, MG
# Identified Tour Eiffel Hotel Benin in Porto Novo, BJ
# No hotel found for Amapa, BR
# Identified COMBUESA in Ondjiva, AO
# Identified Paradise Inn in Avarua, CK
# Identified JABIR HOTEL in Bandarbeyla, SO
# Identified Pousada Porto De Canoas in Sao Joao Da Barra, BR
# Identified Eden Rock Lodge in Inyonga, TZ
# Identified Cititel Penang in Georgetown, MY
# Identified Shanti Maurice Resort & Spa in Souillac, MU
# Identified Balihai Bungalows in Chicama, PE
# No hotel found for Ndele, CF
# Identified Shiloh Inn Lamesa in Lamesa, US
# Identified LIKWALE LODGE in Mayumba, GA
# Identified Salinas do Maragogi All Inclusive Resort in Maragogi, BR
# Identified Hotel De Paris in Bertoua, CM
# Identified Redface Studios Meublés in Dakar, SN
# Identified Hotel Xaguate in Sao Filipe, CV
# Identified Holiday Inn Express Antofagasta, an IHG Hotel in Antofagasta, CL
# Identified Pousada 100 Passos in Tamandare, BR
# No hotel found for Raga, SS
# Identified Pousada Monte Carmelo O Pão in Belmonte, BR
# Identified Lords Inn Porbandar in Porbandar, IN
# Identified Radisson Blu Resort & Spa - Alibaug, India in Alibag, IN
# Identified Auberge du 11 décembre de la cité CNSS à Manga in Manga, BF
# Identified Al Mumtaz Transport Jiwani in Jiwani, PK
# Identified Casa do Ian😎 in Jacareacanga, BR
# Identified Quality Suites Vila Velha in Vila Velha, BR
# No hotel found for Lagos, NG
# Identified Sunrise Attitude Hotel in Quatre Cocos, MU
# Identified Bothabelo Bed and Breakfast in Phalaborwa, ZA
# Identified Hotel hewa bora in Manono, CD
# Identified Hospedaje Henriquez in Bani, DO
# No hotel found for Mbigou, GA
# Identified Hospitality Carnarvon in Carnarvon, AU
# No hotel found for Adrar, MR
# Identified Hotel California Todos Santos in Todos Santos, MX
# Identified El Medina in Nouadhibou, MR
# Identified Hotel Zawadi in Adjumani, UG
# Identified Taloa Heights in Alofi, NU
# Identified Paraiso Escondido in Mutis, CO
# Identified Sheraton Kauai Coconut Beach Resort in Kapaa, US
# Identified Hotel Plaza Providencia in Ixtapa, MX
# Identified Hôtel Le Dronmi in Cayenne, GF
# Identified Playa Punta Yaya - Las Salinas in Chilca, PE
# Identified Hostal Oro Negro in Talara, PE
# Identified Hotel São Vicente in Araguaina, BR
# Identified HOTEL D'ASSISE in Mossendjo, CG
# Identified Lakeshore Lodge in Kirando, TZ
# Identified Exaunel Hotel Owando in Owando, CG
# Identified Posada del Inti Centro in Mercedes, AR
# Identified Rumah mbah Jamah in Japura, ID
# No hotel found for Tucuma, BR
# No hotel found for Werda, BW
# Identified Monte Carlo in Villa Carlos Paz, AR
# No hotel found for Araouane, ML
# Identified Bungalow 63 in Hambantota, LK
# Identified Haji laloo memon house in Keti Bandar, PK
# Identified Chico's Ranch in Salvador, SV
# Identified Hotel Stardust in Nieuw Amsterdam, SR
# Identified Hotel Touring Club in Trelew, AR
# Identified Auberge Centrale in Natitingou, BJ
# Identified Pereybere Hotel & Spa in Cap Malheureux, MU
# Identified Axim Beach Resort And Spa in Axim, GH
# Identified Kothabalaji in Pulivendla, IN
# Identified Maui Seaside Hotel in Kahului, US
# Identified Hotel Sofitel Montevideo Casino Carrasco and Spa in Paso De Carrasco, UY
# Identified Hotel Vitória in Gurupa, BR
# Identified Posada Villaven C.A. in San Cristobal, VE
# Identified Hotel Bressan in Pontes E Lacerda, BR
# Identified Hotel Mpampa in Soyo, AO
# Identified Le Manotel in Moerai, PF
# Identified Panoramic Sea Resort in Alappuzha, IN
# Identified Banjanay Hotel in Xuddur, SO
# Identified HOTEL BISO NA BISO in Buta, CD
# Identified Motel 6 Sinton, TX in San Patricio, US
# Identified Hotel Du Lac in Inongo, CD
# Identified Hotels in Lakshadweep Islands in Kavaratti, IN
# Identified Hotel Aconcagua in Presidencia Roque Saenz Pena, AR
# Identified ZINGARA 76ft Catamaran, full crew-all included in Road Town, VG
# No hotel found for Nioro, GM
# Identified Hôtel Trois Étoiles de Biltine in Biltine, TD
# Identified Marriott's Ko Olina Beach Club in Makakilo City, US
# Identified HS Hotsson Smart Acapulco in Acapulco, MX
# Identified Hotel Juba in Mogadishu, SO
# Identified Hotel Santa Cruz in Rio Gallegos, AR
# Identified Hotel Las Caobas in San Francisco De Macoris, DO
# Identified Hotel Alegrete in Alegrete, BR
# Identified Hotel Piesta in Trinidad, BO
# Identified Las Cabinas Del Sueño in Nicoya, CR
# Identified Hotel Olako in Omboue, GA
# Identified Hotel Ultramar in Valparaiso, CL
# Identified Cititel Penang in Butterworth, MY
# Identified Huarpes Hotel in San Luis, AR
# Identified Butterfly Beach Hotel in Oistins, BB
# Identified Osprey Beach Hotel in Cockburn Town, TC
# Identified Motel Dos Palmas (Maria Machete) in Primero De Enero, CU
# Identified La Caz Oceane in Saint-leu, RE
# Identified Curubo Hotel in Garowe, SO
# Identified Caribbea Bay Hotel in Kariba, ZW
# Identified Bonthe Holiday Village in Bonthe, SL
# Identified Hotel Morotin in Santa Maria, BR
# Identified Sur Plaza Hotel in Sur, OM
# Identified Halane Hotel and Restaurent in Hobyo, SO
# Identified Miraval Arizona Resort & Spa in Catalina, US
# Identified Clevers Hotel Chiredzi in Chiredzi, ZW
# Identified Movenpick Hotel Doha in Doha, QA
# Identified Mahobilali in Kalemie, CD
# Identified Savannah Inn in Lethem, GY
# No hotel found for Ati, TD
# Identified Hotel Miramar in Huarmey, PE
# Identified Hotel azaf in Sao Desiderio, BR
# Identified Auberge du Routard in Oussouye, SN
# Identified Hotel Náutico de Paita in Paita, PE
# Identified Residencial Karime in Taltal, CL
# Identified Hotel Marilu in Vila Do Maio, CV
# Identified River Place Manor in Upington, ZA
# Identified H10 Taburiente Playa in Santa Cruz De La Palma, ES
# Identified Crôa Mares Hotel in Sao Jose Da Coroa Grande, BR
# Identified Ogomono Doumbo in Douentza, ML
# Identified Makkah Clock Royal Tower, A Fairmont Hotel in Mecca, SA
# Identified Chácara Espaço Dorigon in Campina Grande Do Sul, BR
# Identified Hôtel de l'UCom CVPC in Banikoara, BJ
# Identified Hotel Chik Chik Namibe in Namibe, AO
# Identified Hotel Fellip in Carauari, BR
# Identified jadeja jayendrasinh in Naliya, IN
# Identified Beitbridge Express Hotel in Beitbridge, ZW
# Identified Hospedaje Eco in Lagunas, PE
# No hotel found for Bukama, CD
# Identified Grand Ramela Hotel in Kisangani, CD
# Identified Le Gîte d’Iracoubo in Iracoubo, GF
# Identified Kamaneahn Hotel Inc in Buchanan, LR
# Identified Hotel Millenium in Abaete, BR

# %%
# Assign locations to an array of lat/long pairs
locations = hotel_df[["Lat", "Long"]]

# Assign weights variable to some values
max_temp = hotel_df["Max Temp"]
        
#Assign a fig to the gmaps.figure() attribute
fig = gmaps.figure(center=(0.0, 0.0), 
                   zoom_level=1.5,
                   layout = {'width': '800px',
                             'height': '500px'})

# #assign heatmap layer variable t o heatmap layer attrib and add other dfs
heat_layer = gmaps.heatmap_layer(locations,
                                 weights=[max(temp,0) for temp in max_temp],
                                 dissipating=False,
                                 point_radius=3,
                                 max_intensity=0.95)

# # #Add the heatmap layer.
fig.add_layer(heat_layer)

info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>
"""

hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)

# #Call the figure
fig
# Out:
# Figure(layout=FigureLayout(height='500px', width='800px'))
